# %%
from threshold import *
import PATHS

obj1 = Threshold(PATHS.LANGS[1:obj.lang2num["ro"]] + PATHS.LANGS[(obj.lang2num["ro"] + 1):])
# obj = Threshold(PATHS.LANGS)

# %%
obj1.print_ranks()
# Out:
# Hello
# +----------+---------------+----------------+
# | Language | Most Similiar | Least Similiar |
# +----------+---------------+----------------+
# |    ar    |       az      |       bs       |
# |    az    |       lv      |       bs       |
# |    bs    |       az      |       gu       |
# |    bg    |       it      |       bs       |
# |    nl    |       de      |       gu       |
# |    fr    |       it      |       bs       |
# |    de    |       it      |       bs       |
# |    gu    |       az      |       bs       |
# |    hi    |       az      |       bs       |
# |    hu    |       it      |       gu       |
# |    id    |       it      |       bs       |
# |    it    |       de      |       bs       |
# |    lv    |       az      |       bs       |
# |    sr    |       lv      |       bs       |
# |    es    |       it      |       gu       |
# |    sv    |       it      |       gu       |
# |    ta    |       az      |       bs       |
# ...

# %%
obj1.print_ranks()
# Out:
# Hello
# +----------+---------------+----------------+
# | Language | Most Similiar | Least Similiar |
# +----------+---------------+----------------+
# |    ar    |       az      |       ro       |
# |    az    |       lv      |       ro       |
# |    bs    |       az      |       ro       |
# |    bg    |       it      |       ro       |
# |    nl    |       de      |       gu       |
# |    fr    |       it      |       bs       |
# |    de    |       it      |       ro       |
# |    gu    |       az      |       ro       |
# |    hi    |       az      |       ro       |
# |    hu    |       it      |       ro       |
# |    id    |       it      |       ro       |
# |    it    |       de      |       ro       |
# |    lv    |       az      |       ro       |
# |    ro    |       it      |       gu       |
# |    sr    |       lv      |       ro       |
# |    es    |       it      |       ro       |
# |    sv    |       it      |       ro       |
# ...

# %%
obj.get_
# Out:
# +-------------+----------------------------------------------------------------------------------+
# | Translation |                                      Result                                      |
# +-------------+----------------------------------------------------------------------------------+
# |   en to ar  | +------------------+-----------------+----------------+----------------+-------+ |
# |             | |                  | Both High Score | One High Score | Both Low Score | Total | |
# |             | +------------------+-----------------+----------------+----------------+-------+ |
# |             | | High Homogeneity |       558       |      224       |       2        |  784  | |
# |             | | Low Homogeniety  |       2706      |      2029      |      278       |  5013 | |
# |             | |      Total       |       3264      |      2253      |      280       |  5797 | |
# ...
